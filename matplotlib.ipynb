# %%
# Foot preference of FIFA players

import pandas as pd
import matplotlib.pyplot as plt
fifa = pd.read_csv("fifa_data.csv", encoding="Latin-1")
fifa["Overall"]
#fifa.loc[fifa["Preferred Foot"]=="Left"].count()
# Out:
# 0        94
# 1        94
# 2        92
# 3        91
# 4        91
# 5        91
# 6        91
# 7        91
# 8        91
# 9        90
# 10       90
# 11       90
# 12       90
# 13       90
# 14       89
# 15       89
# 16       89
# 17       89
# 18       89
# 19       89
# 20       89
# 21       89
# 22       89
# 23       89
# 24       89
# 25       88
# 26       88
# 27       88
# 28       88
# 29       88
#          ..
# 18177    48
# 18178    48
# 18179    48
# 18180    48
# 18181    48
# 18182    48
# 18183    48
# 18184    48
# 18185    48
# 18186    47
# 18187    47
# 18188    47
# 18189    47
# 18190    47
# 18191    47
# 18192    47
# 18193    47
# 18194    47
# 18195    47
# 18196    47
# 18197    47
# 18198    47
# 18199    47
# 18200    47
# 18201    47
# 18202    47
# 18203    47
# 18204    47
# 18205    47
# 18206    46
# Name: Overall, Length: 18207, dtype: int64

# %%
#left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()0]
fifa['Preferred Foot'].value_counts()[1]
# Out:
# 4211

# %%
fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

# %%
import matplotlib.pyplot as plt

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(5,3))


labels = ['Left', 'Right']
colors = ['blue', 'green']

plt.pie([left, right], labels = labels,  colors=colors)

plt.title('Foot Preference of FIFA Players')

plt.show()

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right =fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(5,3))


values = [left,right]
colors = ['blue', 'green']

plt.bar(['left', 'right'],values,color="blue")

plt.title('Foot Preference of FIFA Players')

plt.show()

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(5,3))

labels = ['Left', 'Right']
colors = ['powderblue', 'yellow']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.3f %%')

plt.title('Foot Preference of FIFA Players')

plt.show()

# %%
# Distribution of players skills in Fifa 2018
# %matplotlib inline
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(15,8))

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

#plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.jpg', dpi=300)

plt.show()

# %%
fifa["Weight"]
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
# 5        163.0
# 6        146.0
# 7        190.0
# 8        181.0
# 9        192.0
# 10       176.0
# 11       168.0
# 12       172.0
# 13       148.0
# 14       159.0
# 15       165.0
# 16       196.0
# 17       161.0
# 18       187.0
# 19       212.0
# 20       168.0
# 21       170.0
# 22       203.0
# 23       154.0
# 24       187.0
# 25       161.0
# 26       157.0
# 27       185.0
# 28       172.0
# 29       130.0
#          ...
# 18177    163.0
# 18178    176.0
# 18179    163.0
# 18180    172.0
# 18181    134.0
# 18182    165.0
# 18183    190.0
# 18184    179.0
# 18185    159.0
# 18186    174.0
# 18187    161.0
# 18188    148.0
# 18189    165.0
# 18190    176.0
# 18191    168.0
# 18192    165.0
# 18193    146.0
# 18194    187.0
# 18195    141.0
# 18196    146.0
# 18197    141.0
# 18198    154.0
# 18199    150.0
# 18200    157.0
# 18201    168.0
# 18202    134.0
# 18203    170.0
# ...

# %%
# weight of profession soccer players

plt.figure(figsize=(8,5), dpi=100)

#plt.style.use('ggplot')

#fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa.loc[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = 'under 125', '125-150', '150-175', '175-200', 'over 200'
explode = (.4,.3,0,0,.4)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label,explode=explode,pctdistance=.8,autopct='%.2f %%')
plt.show()

# %%
# weight of profession soccer players
plt.figure(figsize=(8,5), dpi=100)
#plt.style.use('ggplot')
fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]
light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa.loc[fifa.Weight >= 200].count()[0]
weights = [light,light_medium, medium, medium_heavy, heavy]
label = 'under 125', '125-150', '150-175', '175-200', 'over 200'
plt.title('Weight of Professional Soccer Players (lbs)')
plt.bar(label, weights)
plt.show()

# %%
# gas Prices over time in USD
import pandas as pd
import matplotlib.pyplot as plt
gas = pd.read_csv("gas-prices.csv")
gas
# Out:
#     Unnamed: 0  Year  Australia  Canada  France  Germany  Italy  Japan  \
# 0            0  1990        NaN    1.87    3.63     2.65   4.59   3.16
# 1            1  1991       1.96    1.92    3.45     2.90   4.50   3.46
# 2            2  1992       1.89    1.73    3.56     3.27   4.53   3.58
# 3            3  1993       1.73    1.57    3.41     3.07   3.68   4.16
# 4            4  1994       1.84    1.45    3.59     3.52   3.70   4.36
# 5            5  1995       1.95    1.53    4.26     3.96   4.00   4.43
# 6            6  1996       2.12    1.61    4.41     3.94   4.39   3.64
# 7            7  1997       2.05    1.62    4.00     3.53   4.07   3.26
# 8            8  1998       1.63    1.38    3.87     3.34   3.84   2.82
# 9            9  1999       1.72    1.52    3.85     3.42   3.87   3.27
# 10          10  2000       1.94    1.86    3.80     3.45   3.77   3.65
# 11          11  2001       1.71    1.72    3.51     3.40   3.57   3.27
# ...

# %%
plt.figure(figsize=(10,7))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-', label="Canada")
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas.Australia, 'y.-')

plt.legend()

# %%
# Another Way to plot many values!
countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']

plt.figure(figsize=(18,10))
for country in gas:
     if country in countries_to_look_at:
            plt.plot(gas.Year, gas[country], marker='.')

# %%
# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')

plt.xticks(gas.Year[::4].tolist())
print(gas.Year[::4])
plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()
plt.plot(gas.Year, gas['USA'], marker='.')
plt.plot(gas.Year, gas['Canada'],marker='+')
plt.savefig('Gas_price_figure1.png', dpi=300)

plt.show()
# Out:
# No handles with labels found to put in legend.
# 0     1990
# 4     1994
# 8     1998
# 12    2002
# 16    2006
# Name: Year, dtype: int64

# %%
# weight of profession soccer players

plt.figure(figsize=(8,5), dpi=100)

#plt.style.use('ggplot')

fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]

# %%
# Import Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv")
x = df['date']; y1 = df['psavert']; y2 = df['unemploy']

# Plot Line1 (Left Y Axis)
fig, ax1 = plt.subplots(1,1,figsize=(16,7), dpi= 80)
ax1.plot(x, y1, color='tab:red')

# Plot Line2 (Right Y Axis)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(x, y2, color='tab:blue')

# Just Decorations!! -------------------
# ax1 (left y axis)
ax1.set_xlabel('Year', fontsize=20)
ax1.set_ylabel('Personal Savings Rate', color='tab:red', fontsize=20)
ax1.tick_params(axis='y', rotation=0, labelcolor='tab:red' )

# ax2 (right Y axis)
ax2.set_ylabel("# Unemployed (1000's)", color='tab:blue', fontsize=20)
ax2.tick_params(axis='y', labelcolor='tab:blue')
ax2.set_title("Personal Savings Rate vs Unemployed: Plotting in Secondary Y Axis", fontsize=20)
ax2.set_xticks(np.arange(0, len(x), 60))
ax2.set_xticklabels(x[::60], rotation=90, fontdict={'fontsize':10})
plt.show()

# %% [markdown]
# # Different types of plots

# %%
import pandas as pd

# Setup the subplot2grid Layout
fig = plt.figure(figsize=(10, 5))
ax1 = plt.subplot2grid((2,4), (0,0)) 
ax2 = plt.subplot2grid((2,4), (0,1)) 
ax3 = plt.subplot2grid((2,4), (0,2)) 
ax4 = plt.subplot2grid((2,4), (0,3)) 
ax5 = plt.subplot2grid((2,4), (1,0), colspan=2) 
ax6 = plt.subplot2grid((2,4), (1,2)) 
ax7 = plt.subplot2grid((2,4), (1,3)) 

# Input Arrays
n = np.array([0,1,2,3,4,5])
x = np.linspace(0,5,10)
xx = np.linspace(-0.75, 1., 100)

# Scatterplot
ax1.scatter(xx, xx + np.random.randn(len(xx)))
ax1.set_title("Scatter Plot")

# Step Chart
ax2.step(n, n**2, lw=2)
ax2.set_title("Step Plot")

# Bar Chart
ax3.bar(n, n**2, align="center", width=0.5, alpha=0.5)
ax3.set_title("Bar Chart")

# Fill Between
ax4.fill_between(x, x**2, x**3, color="steelblue", alpha=0.5);
ax4.set_title("Fill Between");

# Time Series
dates = pd.date_range('2018-01-01', periods = len(xx))
ax5.plot(dates, xx + np.random.randn(len(xx)))
ax5.set_xticks(dates[::30])
ax5.set_xticklabels(dates.strftime('%Y-%m-%d')[::30])
ax5.set_title("Time Series")

# Box Plot
ax6.boxplot(np.random.randn(len(xx)))
ax6.set_title("Box Plot")

# Histogram
ax7.hist(xx + np.random.randn(len(xx)))
ax7.set_title("Histogram")

fig.tight_layout()

# %% [markdown]
# # Seaborn

# %%
#As the charts get more complex, the more the code you’ve got to write. For example, in matplotlib, 
#there is no direct method to draw a density plot of a scatterplot with line of best fit. 

#So,  use a higher level package like seaborn, and use one of its prebuilt functions to draw the plot.

# %%
import seaborn as sns
sns.set_style("white")

# Import Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
sns.kdeplot(df.loc[df['cyl'] == 4, "cty"], shade=True, color="g", label="Cyl=4", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 6, "cty"], shade=True, color="dodgerblue", label="Cyl=6", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 8, "cty"], shade=True, color="orange", label="Cyl=8", alpha=.7)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
plt.legend()
plt.show()

# %%
# Load Dataset
df = sns.load_dataset('iris')

# Plot
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(df, kind="reg", hue="species")
plt.show()

# %%
numpy.random.randint() is one of the function for doing random sampling in numpy. It returns an array of specified shape and fills it with random integers from low (inclusive) to high (exclusive), i.e. in the interval [low, high)

# %%
import numpy as geek 
  
# output array 
out_arr = geek.random.randint(low = 0, high = 3, size = 5) 
print ("Output 1D Array filled with random integers : ", out_arr)
# Out:
# Output 1D Array filled with random integers :  [0 1 1 0 1]

# %%
import numpy as geek 
  
  
# output array 
out_arr = geek.random.randint(low = 4, size =(2, 3)) 
print ("Output 2D Array filled with random integers : ", out_arr)
# Out:
# Output 2D Array filled with random integers :  [[1 0 1]
#  [1 3 0]]

# %%
import numpy as geek 
  
# output array 
out_arr = geek.random.randint(2, 10, (2, 3, 4)) 
print ("Output 3D Array filled with random integers : ", out_arr)
# Out:
# Output 3D Array filled with random integers :  [[[5 6 8 8]
#   [7 9 5 9]
#   [8 2 5 2]]
#
#  [[8 5 5 9]
#   [3 5 2 5]
#   [3 4 2 9]]]

# %%
rng = np.arange(50)
print(rng.size)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng
np.random.randint?
fig, ax = plt.subplots(figsize=(8, 5))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()
# Out:
# 50
